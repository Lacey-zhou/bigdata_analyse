# %% [markdown]
# # 1、 数据集说明
#
# 这是一份来自[和鲸社区](https://www.kesci.com/mw/dataset/5e023cd12823a10036af49b4/file)的倒闭企业数据集，总计 6,272 条记录，大小为 2.3 M，包含 21 个字段。

# %%
import pandas as pd 
data = pd.read_csv('com.csv')
data.head()
# Out:
#    bianh com_name com_addr   cat   se_cat  \
# 0      1     麦子金服       上海    金融       借贷
# 1      1     拓道金服       浙江    金融       借贷
# 2      1     云柏科技       广东  医疗健康  医疗器械及硬件
# 3      1     迷你生鲜       福建  电子商务     生鲜食品
# 4      1     一生健康       北京  医疗健康     寻医诊疗
#
#                                              com_des   born_data  death_data  \
# 0  麦子金服是一家移动互联网金融服务集团，为个人和企业提供包括财富管理、股权投资、投融资咨询等综...  2015-03-01  2019-11-25
# 1  拓道金服是一家专注于汽车抵押贷款这一细分市场的P2P互联网金融公司。拓道金服通过互联网民间的...  2013-11-01  2019-11-24
# 2  云柏科技是一家智能健康检测腕表研发商，专注于智能可穿戴设备领域。主要产品包括可穿戴式多功能云...  2014-09-01  2019-11-01
# 3  迷你生鲜是一家会员制水果生鲜电商网站，平台产品由基地直供，采购深入全国及东南亚各地区，减少中...  2017-11-01  2019-10-29
# 4  微爱康一款基于移动互联网的癌症患者互助型垂直社区产品，通过在线社会化问答和类轻博客交流模式，...  2015-01-01  2019-10-17
#
#    live_days financing  ...  death_reason       invest_name ceo_name ceo_des  \
# 0       1730        B轮  ...   政策监管 法律法规风险         海通开元&中缔资本      黄大容     董事长
# 1       2214        A轮  ...   政策监管 法律法规风险  蓝山中国资本&帮实资本&宏桥资本      张罗军     创始人
# 2       1887      尚未获投  ...          行业竞争               NaN      NaN     NaN
# 3        727      尚未获投  ...    现金流断裂 行业竞争               NaN      NaN     NaN
# 4       1750      尚未获投  ...   政策监管 法律法规风险               NaN      张耀斌     CEO
#
#                                          ceo_per_des Unnamed: 16  Unnamed: 17  \
# 0  黄大容，80后，经济学硕士，精通中英德三国语言。连续创业者，23岁创立第一家公司，25岁涉足...         NaN          NaN
# 1  杭州拓道科技有限公司执行董事兼总经理，重庆邮电学院计算机专业，创立杭州仁润科技有限公司，具有...         NaN          NaN
# 2                                                NaN         NaN          NaN
# 3                                                NaN         NaN          NaN
# 4                           张耀斌，为一生（北京）健康科技有限公司的创始人。         NaN          NaN
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # 2、数据分析可视化

# %% [markdown]
# ## 2.1 死亡公司的地区分布

# %%
data['com_addr'].unique()
# Out:
# array(['上海', '浙江', '广东', '福建', '北京', '湖南', '江苏', '四川', '陕西', '河北', '吉林',
#        '湖北', '河南', '天津', '贵州', '山东', '重庆', '辽宁', '安徽', '江西', '亚洲', '北美洲',
#        '广西', '山西', '黑龙江', '香港', '新疆', '台湾', '青海', '云南', '甘肃', '欧洲', '海南',
#        '内蒙古', '宁夏', '西藏'], dtype=object)

# %%
# 定义映射表：简称 → 标准全称
addr_mapping = {
    # 直辖市
    "上海": "上海市",
    "北京": "北京市",
    "天津": "天津市",
    "重庆": "重庆市",
    # 省份
    "浙江": "浙江省",
    "广东": "广东省",
    "福建": "福建省",
    "湖南": "湖南省",
    "江苏": "江苏省",
    "四川": "四川省",
    "陕西": "陕西省",
    "河北": "河北省",
    "吉林": "吉林省",
    "湖北": "湖北省",
    "河南": "河南省",
    "贵州": "贵州省",
    "山东": "山东省",
    "辽宁": "辽宁省",
    "安徽": "安徽省",
    "江西": "江西省",
    "广西": "广西壮族自治区",
    "山西": "山西省",
    "黑龙江": "黑龙江省",
    "新疆": "新疆维吾尔自治区",
    "台湾": "台湾省",
    "青海": "青海省",
    "云南": "云南省",
    "甘肃": "甘肃省",
    "海南": "海南省",
    "内蒙古": "内蒙古自治区",
    "宁夏": "宁夏回族自治区",
    "西藏": "西藏自治区"
}

# 批量替换：若在映射表中则替换，否则保留原值
data['com_addr'] = data['com_addr'].map(lambda x: addr_mapping.get(x, x))

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

data['com_addr'] = data['com_addr'].apply(lambda x: x.strip())
s = data.groupby('com_addr').size()

c = (
Map()
    .add("死亡企业数量", [*s.items()], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="地区分布"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="8affbb692b3742fba1a46a0819a66bf9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8affbb692b3742fba1a46a0819a66bf9 = echarts.init(
#                     document.getElementById('8affbb692b3742fba1a46a0819a66bf9'), 'white', {renderer: 'canvas'});
#                 var option_8affbb692b3742fba1a46a0819a66bf9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 1034
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e9a\u6d32",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 2239
#                 },
#                 {
#                     "name": "\u5317\u7f8e\u6d32",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u53f0\u6e7e\u7701",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5409\u6797\u7701",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": 282
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u5c71\u4e1c\u7701",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u5c71\u897f\u7701",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 1095
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6b27\u6d32",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u7701",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6cb3\u5357\u7701",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u6d77\u5357\u7701",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u798f\u5efa\u7701",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u897f\u85cf\u81ea\u6cbb\u533a",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81\u7701",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u9655\u897f\u7701",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9752\u6d77\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f\u7701",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5730\u533a\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "co

# %% [markdown]
# ## 2.2 行业排行TOP10

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

s = data.groupby('cat').size().sort_values(ascending=False)[:10].to_dict()

c = (
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("死亡企业数量", list(s.values()))
    .set_global_opts(title_opts=opts.TitleOpts(title="行业排行TOP10"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aef92021621a4760b6854cb1d4c46c5d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aef92021621a4760b6854cb1d4c46c5d = echarts.init(
#                     document.getElementById('aef92021621a4760b6854cb1d4c46c5d'), 'white', {renderer: 'canvas'});
#                 var option_aef92021621a4760b6854cb1d4c46c5d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 925,
#                 789,
#                 595,
#                 510,
#                 500,
#                 421,
#                 376,
#                 374,
#                 334,
#                 311
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u751f\u6d3b",
#                 "\u91d1\u878d",
#                 "\u793e\u4ea4\u7f51\u7edc",
#                 "\u6587\u5a31\u4f20\u5a92",
#                 "\u6559\u80b2",
#                 "\u5de5\u5177\u8f6f\u4ef6",
#                 "\u6e38\u620f",
#                 "\u6c7d\u8f66\u4ea4\u901a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u884c\u4e1a\u6392\u884cTOP10",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_aef92021621a4760b6854cb1d4c46c5d.setOption(option_aef92021621a4760b6854cb1d4c46c5d);
#         });
#     </script>

# %% [markdown]
# ## 2.3 细分领域TOP20

# %%
s = data.groupby('se_cat').size().sort_values(ascending=False)[:20].sort_values(ascending=True).to_dict()

c = (
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("死亡企业数量", list(s.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="细分领域TOP20"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f7a94a81c0a843c892d67f21a20ae6d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f7a94a81c0a843c892d67f21a20ae6d7 = echarts.init(
#                     document.getElementById('f7a94a81c0a843c892d67f21a20ae6d7'), 'white', {renderer: 'canvas'});
#                 var option_f7a94a81c0a843c892d67f21a20ae6d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 83,
#                 91,
#                 95,
#                 100,
#                 103,
#                 110,
#                 111,
#                 112,
#                 119,
#                 119,
#                 120,
#                 124,
#                 129,
#                 136,
#                 139,
#                 145,
#                 149,
#                 162,
#                 224,
#                 240
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "\u513f\u7ae5\u65e9\u6559",
#                 "\u4e8b\u9879\u53ca\u6548\u7387",
#                 "\u5176\u4ed6\u7535\u5546\u670d\u52a1",
#                 "\u4ea4\u901a\u51fa\u884c",
#                 "\u6574\u5408\u8425\u9500\u4f20\u64ad",
#                 "\u7406\u8d22",
#                 "\u670d\u88c5\u670d\u9970",
#                 "\u5a92\u4f53\u53ca\u9605\u8bfb",
#                 "\u751f\u9c9c\u98df\u54c1",
#                 "\u964c\u751f\u4eba\u4ea4\u53cb",
#                 "\u5176\u4ed6\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u7efc\u5408\u751f\u6d3b",
#                 "\u4eba\u529b\u8d44\u6e90",
#                 "\u7535\u5546\u89e3\u51b3\u65b9\u6848",
#                 "\u5174\u8da3\u793e\u533a",
#                 "\u884c\u4e1a\u4fe1\u606f\u5316\u53ca\u89e3\u51b3\u65b9\u6848",
#                 "\u501f\u8d37",
#                 "\u7f8e\u98df\u9910\u996e",
#                 "\u7efc\u5408\u7535\u5546",
#                 "\u6e38\u620f\u5f00\u53d1\u5546"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u7ec6\u5206\u9886\u57dfTOP20",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_f7a94a81c0a843c892d67f21a20ae6d7.setOption(option_f7a94a81c0a843c892d67f21a20ae6d7);
#         });
#     </script>

# %% [markdown]
# ## 2.4 年份分布

# %%
data['born_year'] = data['born_data'].apply(lambda x: x[:4])
data['death_year'] = data['death_data'].apply(lambda x: x[:4])
s1 = data.groupby('born_year').size()
s2 = data.groupby('death_year').size()
s1 = pd.DataFrame({'year': s1.index, 'born': s1.values})
s2 = pd.DataFrame({'year': s2.index, 'death': s2.values})
s = pd.merge(s1,s2, on='year', suffixes=['born', 'death'])
s = s[s['year'] > '2008']

c = (
    Bar()
    .add_xaxis( s['year'].to_list())
    .add_yaxis("新生企业数量", s['born'].to_list())
    .add_yaxis("死亡企业数量", s['death'].to_list())
    .set_global_opts(title_opts=opts.TitleOpts(title="年份分布"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2c1c7fb2b9d549b59057288a56114cac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2c1c7fb2b9d549b59057288a56114cac = echarts.init(
#                     document.getElementById('2c1c7fb2b9d549b59057288a56114cac'), 'white', {renderer: 'canvas'});
#                 var option_2c1c7fb2b9d549b59057288a56114cac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u65b0\u751f\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 164,
#                 268,
#                 583,
#                 940,
#                 1341,
#                 1410,
#                 944,
#                 252,
#                 34,
#                 6,
#                 1
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 40,
#                 57,
#                 70,
#                 182,
#                 335,
#                 1131,
#                 1458,
#                 2145,
#                 458,
#                 327
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65b0\u751f\u4f01\u4e1a\u6570\u91cf",
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u5e74\u4efd\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_2c1c7fb2b9d549b59057288a56114cac.setOption(option_2c1c7fb2b9d549b59057288a56114cac);
#         });
#     </script>

# %% [markdown]
# ## 2.5 企业存活时长

# %%
def live_year(x):
    if x < 365:
        return '不到1年'
    if x < 365 * 2:
        return '1-2年'
    if x < 365 * 3:
        return '2-3年'
    if x < 365 * 4:
        return '3-4年'
    if x < 365 * 5:
        return '4-5年'
    if x < 365 * 10:
        return '5-10年'
    return '10年以上'

s = data.groupby(data['live_days'].apply(lambda x: live_year(x))).size()

from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add("", [*s.items()])
    .set_global_opts(title_opts=opts.TitleOpts(title="企业存活时长"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c8854c782df44d27b7ffa4c345a2ec45" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c8854c782df44d27b7ffa4c345a2ec45 = echarts.init(
#                     document.getElementById('c8854c782df44d27b7ffa4c345a2ec45'), 'white', {renderer: 'canvas'});
#                 var option_c8854c782df44d27b7ffa4c345a2ec45 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "1-2\u5e74",
#                     "value": 644
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 60
#                 },
#                 {
#                     "name": "2-3\u5e74",
#                     "value": 2242
#                 },
#                 {
#                     "name": "3-4\u5e74",
#                     "value": 1108
#                 },
#                 {
#                     "name": "4-5\u5e74",
#                     "value": 954
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 1219
#                 },
#                 {
#                     "name": "\u4e0d\u52301\u5e74",
#                     "value": 45
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-2\u5e74",
#                 "10\u5e74\u4ee5\u4e0a",
#                 "2-3\u5e74",
#                 "3-4\u5e74",
#                 "4-5\u5e74",
#                 "5-10\u5e74",
#                 "\u4e0d\u52301\u5e74"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u4f01\u4e1a\u5b58\u6d3b\u65f6\u957f",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_c8854c782df44d27b7ffa4c345a2ec45.setOption(option_c8854c782df44d27b7ffa4c345a2ec45);
#         });
#     </script>

# %% [markdown]
# ## 2.6 投资人词云

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

invest = {}
for row in data['invest_name'].values:
    if not pd.isnull(row):
        for name in row.split('&'):
            invest[name] = invest.get(name, 0) + 1
invest = [*invest.items()]
invest.sort(key=lambda x: x[1], reverse=True)
c = (
    WordCloud()
    .add("", invest[:150], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="投资人词云"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="b4161661e7974e56a1ea1914f7eae192" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_b4161661e7974e56a1ea1914f7eae192 = echarts.init(
#                     document.getElementById('b4161661e7974e56a1ea1914f7eae192'), 'white', {renderer: 'canvas'});
#                 var option_b4161661e7974e56a1ea1914f7eae192 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5929\u4f7f\u6e7e",
#                     "value": 32,
#                     "textStyle": {
#                         "color": "rgb(87,5,54)"
#                     }
#                 },
#                 {
#                     "name": "\u771f\u683c\u57fa\u91d1",
#                     "value": 30,
#                     "textStyle": {
#                         "color": "rgb(94,100,85)"
#                     }
#                 },
#                 {
#                     "name": "\u9669\u5cf0\u957f\u9752",
#                     "value": 27,
#                     "textStyle": {
#                         "color": "rgb(20,119,157)"
#                     }
#                 },
#                 {
#                     "name": "IDG\u8d44\u672c",
#                     "value": 27,
#                     "textStyle": {
#                         "color": "rgb(93,60,53)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u65b0\u5de5\u573a",
#                     "value": 20,
#                     "textStyle": {
#                         "color": "rgb(138,58,123)"
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7eac\u4e2d\u56fd",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(90,139,153)"
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u6749\u8d44\u672c\u4e2d\u56fd",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(107,112,97)"
#                     }
#                 },
#                 {
#                     "name": "PreAngel",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(87,24,53)"
#                     }
#                 },
#                 {
#                     "name": "\u6885\u82b1\u521b\u6295",
#                     "value": 16,
#                     "textStyle": {
#                         "color": "rgb(1,77,129)"
#                     }
#                 },
#                 {
#                     "name": "\u6668\u5174\u8d44\u672c",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(20,67,82)"
#                     }
#                 },
#                 {
#                     "name": "\u4e5d\u5408\u521b\u6295",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(98,154,128)"
#                     }
#                 },
#                 {
#                     "name": "\u5947\u864e360",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(131,88,144)"
#                     }
#                 },
#                 {
#                     "name": "\u9752\u677e\u57fa\u91d1",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(95,148,30)"
#                     }
#                 },
#                 {
#                     "name": "\u6d2a\u6cf0\u57fa\u91d1",
#                     "value": 9,
#                     "textStyle": {
#                         "color": "rgb(123,51,52)"
#                     }
#                 },
#                 {
#                     "name": "\u6208\u58c1\u521b\u6295",
#                     "value": 9,
#                     "textStyle": {
#                         "color": "rgb(87,121,127)"
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u6c83\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(19,33,31)"
#                     }
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(66,39,29)"
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u8bfa\u5929\u4f7f\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(122,22,156)"
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u8fc5\u6295\u8d44",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(115,57,85)"
#                     }
#                 },
#                 {
#                     "name": "\u7b56\u6e90\u521b\u6295",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(108,83,157)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u4e1a\u63a5\u529b\u5929\u4f7f",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(121,119,57)"
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u6c99\u6c5f\u521b\u6295",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(122,63,95)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u521b\u8d44\u672c",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(146,36,76)"
#                     }
#                 },
#                 {
#                     "name": "\u859b\u86ee\u5b50(\u86ee\u5b50\u57fa\u91d1)",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(8,94,152)"
#                     }
#                 },
#                 {
#                     "name": "\u8f6f\u94f6\u4e2d\u56fd",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(117,124,7)"
#                     }
#                 },
#                 {
#                     "name": "\u5e73\u5b89\u521b\u65b0\u6295\u8d44\u57fa\u91d1",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(93,124,92)"
#                     }
#                 },
#                 {
#                     "name": "\u8054\u60f3\u4e4b\u661f",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(152,148,68)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u8def\u8d44\u672c",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(98,128,32)"

# %% [markdown]
#  ## 2.7 倒闭原因词云

# %%
death_reason = {}
for row in data['death_reason'].values:
    if not pd.isnull(row):
        for name in row.split(' '):
            death_reason[name] = death_reason.get(name, 0) + 1
c = (
    WordCloud()
    .add("", [*death_reason.items()], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="倒闭原因词云"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="51a4b5b38c98418eb0e02bc2662b16f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_51a4b5b38c98418eb0e02bc2662b16f2 = echarts.init(
#                     document.getElementById('51a4b5b38c98418eb0e02bc2662b16f2'), 'white', {renderer: 'canvas'});
#                 var option_51a4b5b38c98418eb0e02bc2662b16f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u653f\u7b56\u76d1\u7ba1",
#                     "value": 88,
#                     "textStyle": {
#                         "color": "rgb(46,38,118)"
#                     }
#                 },
#                 {
#                     "name": "\u6cd5\u5f8b\u6cd5\u89c4\u98ce\u9669",
#                     "value": 65,
#                     "textStyle": {
#                         "color": "rgb(156,86,4)"
#                     }
#                 },
#                 {
#                     "name": "\u884c\u4e1a\u7ade\u4e89",
#                     "value": 354,
#                     "textStyle": {
#                         "color": "rgb(37,20,96)"
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u91d1\u6d41\u65ad\u88c2",
#                     "value": 116,
#                     "textStyle": {
#                         "color": "rgb(33,139,57)"
#                     }
#                 },
#                 {
#                     "name": "\u5546\u4e1a\u6a21\u5f0f\u532e\u4e4f",
#                     "value": 469,
#                     "textStyle": {
#                         "color": "rgb(51,51,80)"
#                     }
#                 },
#                 {
#                     "name": "\u70e7\u94b1",
#                     "value": 83,
#                     "textStyle": {
#                         "color": "rgb(13,40,16)"
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8c03\u6574",
#                     "value": 141,
#                     "textStyle": {
#                         "color": "rgb(96,133,85)"
#                     }
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4f2a\u9700\u6c42",
#                     "value": 217,
#                     "textStyle": {
#                         "color": "rgb(100,141,121)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u5165\u573a\u65f6\u673a",
#                     "value": 113,
#                     "textStyle": {
#                         "color": "rgb(100,137,127)"
#                     }
#                 },
#                 {
#                     "name": "\u878d\u8d44\u80fd\u529b\u4e0d\u8db3",
#                     "value": 107,
#                     "textStyle": {
#                         "color": "rgb(157,142,135)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u7f3a\u9677\u4e25\u91cd",
#                     "value": 31,
#                     "textStyle": {
#                         "color": "rgb(19,127,148)"
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8fc7\u4e8e\u5206\u6563",
#                     "value": 63,
#                     "textStyle": {
#                         "color": "rgb(78,87,9)"
#                     }
#                 },
#                 {
#                     "name": "\u5b9a\u4ef7/\u6210\u672c\u95ee\u9898",
#                     "value": 59,
#                     "textStyle": {
#                         "color": "rgb(102,63,7)"
#                     }
#                 },
#                 {
#                     "name": "\u8425\u9500\u4e0d\u8db3",
#                     "value": 44,
#                     "textStyle": {
#                         "color": "rgb(131,65,41)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba\u95ee\u9898",
#                     "value": 19,
#                     "textStyle": {
#                         "color": "rgb(75,120,12)"
#                     }
#                 },
#                 {
#                     "name": "\u8f6c\u578b\u95ee\u9898",
#                     "value": 39,
#                     "textStyle": {
#                         "color": "rgb(11,69,88)"
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u80fd\u529b\u4e0d\u8db3",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(82,146,96)"
#                     }
#                 },
#                 {
#                     "name": "\u4e0e\u6295\u8d44\u4eba\u51b2\u7a81",
#                     "value": 5,
#                     "textStyle": {
#                         "color": "rgb(69,9,112)"
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u7f3a\u4e4f\u6fc0\u60c5",
#                     "value": 2,
#                     "textStyle": {
#                         "color": "rgb(92,8,78)"
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u91cd\u89c6\u5ba2\u6237",
#                     "value": 11,
#                     "textStyle": {
#                         "color": "rgb(14,118,108)"
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5012\u95ed\u539f\u56e0\u8bcd\u4e91",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign

# %% [markdown]
# ## 2.8 ceo描述词云

# %%
import jieba
ceo_per_des = {}
for row in data['ceo_per_des'].values:
    if not pd.isnull(row):
        result = jieba.lcut(row)
        for name in result:
            if len(name) == 1:
                break
            ceo_per_des[name] = ceo_per_des.get(name, 0) + 1
ceo_per_des = [*ceo_per_des.items()]
ceo_per_des.sort(key=lambda x: x[1], reverse=True)
c = (
    WordCloud()
    .add("", ceo_per_des[:100], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="ceo描述词云"))
)
c.render_notebook()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/j9/hzn1x0p94y9cqn386_rm08180000gn/T/jieba.cache
# Loading model cost 0.247 seconds.
# Prefix dict has been built successfully.
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="93a72a6b72034f3d92287f1f2f662b22" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_93a72a6b72034f3d92287f1f2f662b22 = echarts.init(
#                     document.getElementById('93a72a6b72034f3d92287f1f2f662b22'), 'white', {renderer: 'canvas'});
#                 var option_93a72a6b72034f3d92287f1f2f662b22 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6709\u9650\u516c\u53f8",
#                     "value": 245,
#                     "textStyle": {
#                         "color": "rgb(113,145,80)"
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u6280",
#                     "value": 125,
#                     "textStyle": {
#                         "color": "rgb(127,54,33)"
#                     }
#                 },
#                 {
#                     "name": "\u6267\u884c",
#                     "value": 100,
#                     "textStyle": {
#                         "color": "rgb(69,77,108)"
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b",
#                     "value": 100,
#                     "textStyle": {
#                         "color": "rgb(150,36,149)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba",
#                     "value": 95,
#                     "textStyle": {
#                         "color": "rgb(45,66,78)"
#                     }
#                 },
#                 {
#                     "name": "CEO",
#                     "value": 86,
#                     "textStyle": {
#                         "color": "rgb(42,31,23)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 72,
#                     "textStyle": {
#                         "color": "rgb(80,123,35)"
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 51,
#                     "textStyle": {
#                         "color": "rgb(109,59,113)"
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc\u79d1\u6280",
#                     "value": 41,
#                     "textStyle": {
#                         "color": "rgb(37,143,16)"
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": 30,
#                     "textStyle": {
#                         "color": "rgb(98,137,53)"
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 25,
#                     "textStyle": {
#                         "color": "rgb(135,120,102)"
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b\u957f",
#                     "value": 25,
#                     "textStyle": {
#                         "color": "rgb(5,120,140)"
#                     }
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 24,
#                     "textStyle": {
#                         "color": "rgb(63,35,130)"
#                     }
#                 },
#                 {
#                     "name": "\u4fe1\u606f",
#                     "value": 22,
#                     "textStyle": {
#                         "color": "rgb(23,120,14)"
#                     }
#                 },
#                 {
#                     "name": "\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(3,126,76)"
#                     }
#                 },
#                 {
#                     "name": "\u6295\u8d44",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(78,128,115)"
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(155,37,89)"
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(39,46,59)"
#                     }
#                 },
#                 {
#                     "name": "\u6bd5\u4e1a",
#                     "value": 14,
#                     "textStyle": {
#                         "color": "rgb(26,128,110)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 14,
#                     "textStyle": {
#                         "color": "rgb(159,117,150)"
#                     }
#                 },
#                 {
#                     "name": "\u7ba1\u7406",
#                     "value": 14,
#                     "textStyle": {
#                         "color": "rgb(137,33,40)"
#                     }
#                 },
#                 {
#                     "name": "\u6709\u9650\u8d23\u4efb",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(98,131,151)"
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(48,84,117)"
#                     }
#                 },
#                 {
#                     "name": "\u6587\u5316",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(89,41,56)"
#                     }
#                 },
#                 {
#                     "name": "\u6280\u672f",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(90,57,26)"
#                     }
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u6280\u672f",
#                     "value": 11,
#                     "textStyle": {
#                         "color": "rgb(97,40,100)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u4e1a\u8005",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(102,19,62)"
#                     }
#                 },
#                 {
#                     "name": "\u6587\u5316\u4f20\u5a92",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(21,0,156)"
#                     }
#                 },
#                 {
#                     "name": "\u54a8\u8be2",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(46,6,11)"
#                     }
#                 },
